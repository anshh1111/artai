# %%
import base64

encoded_string = "AHas8cBZ-Dpi0dfeme7_1KFW2fXE7lm_5_HNitfFXOujK9QJu5UJ4WEcSDMgqysxDeP53bMV2IyJCvz_g0cg"

# Decode Base64
decoded_bytes = base64.urlsafe_b64decode(encoded_string + "==")

# Display decoded bytes
print(decoded_bytes)
# Out:
# b'\x00v\xac\xf1\xc0Y\xf8:b\xd1\xd7\xde\x99\xee\xff\xd4\xa1V\xd9\xf5\xc4\xeeY\xbf\xe7\xf1\xcd\x8a\xd7\xc5\\\xeb\xa3+\xd4\t\xbb\x95\t\xe1a\x1cH3 \xab+1\r\xe3\xf9\xdd\xb3\x15\xd8\x8c\x89\n\xfc\xff\x83G '
